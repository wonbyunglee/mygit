# %%
# club

import pandas as pd
import numpy as np
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, f1_score, roc_auc_score, matthews_corrcoef
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from imblearn.over_sampling import RandomOverSampler

data = pd.read_csv("C:\\Users\\co279\\penalty.csv")

data = data.iloc[:, 4:]
data.dropna(inplace=True)

# data preprocessing
data = pd.get_dummies(data, columns=['position'])
data = pd.get_dummies(data, columns=['order'])

label_encoder = LabelEncoder()
data['score'] = label_encoder.fit_transform(data['score'])

X = data.drop(columns=['score'])
y = data['score']

accuracy_list = []
f1_list = []
roc_list = []
mcc_list = []

# iteration = 5
n_iterations = 5

for i in range(n_iterations):
    # data spliting (train, test)
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=411 + i, stratify=y)

    # oversampling
    oversampler = RandomOverSampler(sampling_strategy='minority', random_state=411)
    X_resampled, y_resampled = oversampler.fit_resample(X_train, y_train)

    # multi-layer perceptron
    model = Sequential()
    model.add(Dense(64, activation='relu', input_shape=(X_resampled.shape[1],)))
    model.add(Dense(32, activation='relu'))
    model.add(Dense(16, activation='relu'))
    model.add(Dense(1, activation='sigmoid'))

    # model compiling
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

    # model fitting
    model.fit(X_resampled, y_resampled, epochs=10, batch_size=8, validation_data=(X_test, y_test), callbacks=[tf.keras.callbacks.EarlyStopping(patience=3, monitor='val_loss')])

    y_pred_prob = model.predict(X_test)
    y_pred = [1 if prob > 0.5 else 0 for prob in y_pred_prob]

    # model evaluation
    accuracy = accuracy_score(y_test, y_pred)
    f1 = f1_score(y_test, y_pred)
    roc = roc_auc_score(y_test, y_pred)
    mcc = matthews_corrcoef(y_test, y_pred)

    accuracy_list.append(accuracy)
    f1_list.append(f1)
    roc_list.append(roc)
    mcc_list.append(mcc)

    print(f"Iteration {i+1} - accuracy: {accuracy}, f1_score: {f1}, roc_auc: {roc}, MCC: {mcc}")

# average
avg_accuracy = np.mean(accuracy_list)
avg_f1 = np.mean(f1_list)
avg_roc = np.mean(roc_list)
avg_mcc = np.mean(mcc_list)

print("\nAverage Metrics after 5 Iterations:")
print(f"Average accuracy: {avg_accuracy}")
print(f"Average f1_score: {avg_f1}")
print(f"Average roc_auc: {avg_roc}")
print(f"Average MCC: {avg_mcc}")
# Out:
# Epoch 1/10
# 333/333 [==============================] - 2s 3ms/step - loss: 0.7676 - accuracy: 0.5229 - val_loss: 0.7128 - val_accuracy: 0.4114
# Epoch 2/10
# 333/333 [==============================] - 1s 2ms/step - loss: 0.6918 - accuracy: 0.5270 - val_loss: 0.7114 - val_accuracy: 0.4068
# Epoch 3/10
# 333/333 [==============================] - 1s 2ms/step - loss: 0.6906 - accuracy: 0.5428 - val_loss: 0.7204 - val_accuracy: 0.4068
# Epoch 4/10
# 333/333 [==============================] - 1s 2ms/step - loss: 0.6880 - accuracy: 0.5349 - val_loss: 0.6466 - val_accuracy: 0.7386
# Epoch 5/10
# 333/333 [==============================] - 1s 2ms/step - loss: 0.6894 - accuracy: 0.5394 - val_loss: 0.6865 - val_accuracy: 0.4273
# Epoch 6/10
# 333/333 [==============================] - 1s 2ms/step - loss: 0.6878 - accuracy: 0.5409 - val_loss: 0.7423 - val_accuracy: 0.3727
# Epoch 7/10
# 333/333 [==============================] - 1s 2ms/step - loss: 0.6870 - accuracy: 0.5473 - val_loss: 0.6647 - val_accuracy: 0.6795
# 14/14 [==============================] - 0s 1ms/step
# Iteration 1 - accuracy: 0.6795454545454546, f1_score: 0.36771300448430494, roc_auc: 0.579623771325274, MCC: 0.1541362232697253
# Epoch 1/10
# 333/333 [==============================] - 2s 2ms/step - loss: 0.6982 - accuracy: 0.5267 - val_loss: 0.6705 - val_accuracy: 0.4682
# Epoch 2/10
# 333/333 [==============================] - 1s 2ms/step - loss: 0.6856 - accuracy: 0.5454 - val_loss: 0.6696 - val_accuracy: 0.4659
# Epoch 3/10
# 333/333 [==============================] - 1s 2ms/step - loss: 0.6855 - accuracy: 0.5480 - val_loss: 0.6815 - val_accuracy: 0.4045
# Epoch 4/10
# 333/333 [==============================] - 1s 2ms/step - loss: 0.6851 - accuracy: 0.5443 - val_loss: 0.6831 - val_accuracy: 0.4114
# Epoch 5/10
# 333/333 [==============================] - 1s 2ms/step - loss: 0.6846 - accuracy: 0.5492 - val_loss: 0.6837 - val_accuracy: 0.4068
# 14/14 [==============================] - 0s 1ms/step
# Iteration 2 - accuracy: 0.4068181818181818, f1_score: 0.4, roc_auc: 0.5481019093887696, MCC: 0.09472378409088433
# Epoch 1/10
# 333/333 [==============================] - 2s 3ms/step - loss: 0.8340 - accuracy: 0.5214 - val_loss: 0.7117 - val_accuracy: 0.4205
# Epoch 2/10
# 333/333 [==============================] - 1s 2ms/step - loss: 0.6953 - accuracy: 0.5398 - val_loss: 0.6660 - val_accuracy: 0.6091
# Epoch 3/10
# 333/333 [==============================] - 1s 2ms/step - loss: 0.6803 - accuracy: 0.5807 - val_loss: 0.5921 - val_accuracy: 0.7318
# Epoch 4/10
# 333/333 [==============================] - 1s 2ms/step - loss: 0.6857 - accuracy: 0.5623 - val_loss: 0.6582 - val_accuracy: 0.6136
# Epoch 5/10
# 333/333 [==============================] - 1s 2ms/step - loss: 0.6762 - accuracy: 0.5709 - val_loss: 0.6406 - val_accuracy: 0.6523
# Epoch 6/10
# 333/333 [==============================] - 1s 2ms/step - loss: 0.6709 - accuracy: 0.5770 - val_loss: 0.7530 - val_accuracy: 0.4477
# 14/14 [==============================] - 0s 1ms/step
# Iteration 3 - accuracy: 0.44772727272727275, f1_score: 0.3848101265822785, roc_auc: 0.539628290588634, MCC: 0.07138781764977484
# Epoch 1/10
# 333/333 [==============================] - 2s 3ms/step - loss: 0.7607 - accuracy: 0.5139 - val_loss: 0.6096 - val_accuracy: 0.7455
# Epoch 2/10
# 333/333 [==============================] - 1s 2ms/step - loss: 0.7064 - accuracy: 0.5469 - val_loss: 0.8519 - val_accuracy: 0.2614
# Epoch 3/10
# 333/333 [==============================] - 1s 2ms/step - loss: 0.6905 - accuracy: 0.5420 - val_loss: 0.6852 - val_accuracy: 0.4432
# Epoch 4/10
# 333/333 [==============================] - 1s 2ms/step - loss: 0.6855 - accuracy: 0.5533 - val_loss: 0.6213 - val_accuracy: 0.7659
# 14/14 [==============================] - 0s 1ms/step
# Iteration 4 - accuracy: 0.7659090909090909, f1_score: 0.21374045801526717, roc_auc: 0.5495706699807931, MCC: 0.18314155517079572
# Epoch 1/10
# 333/333 [==============================] - 2s 2ms/step - loss: 0.7475 - accuracy: 0.5304 - val_loss: 0.5713 - val_accuracy: 0.7614
# Epoch 2/10
# 333/333 [==============================] - 1s 2ms/step - loss: 0.7006 - accuracy: 0.5282 - val_loss: 0.6071 - val_accuracy: 0.7455
# Epoch 3/10
# 333/333 [==============================] - 1s 2ms/step - loss: 0.6897 - accuracy: 0.5544 - val_loss: 0.7243 - val_accuracy: 0.3977
# Epoch 4/10
# 333/333 [==============================] - 1s 2ms/step - loss: 0.6851 - accuracy: 0.5755 - val_loss: 0.6689 - val_accuracy: 0.5977
# 14/14 [==============================] - 0s 1ms/step
# Iteration 5 - accuracy: 0.5977272727272728, f1_score: 0.39590443686006827, roc_auc: 0.5804711332052875, MCC: 0.13922435514315104
#
# Average Metrics after 5 Iterations:
# Average accuracy: 0.5795454545454545
# Average f1_score: 0.35243360518838374
# Average roc_auc: 0.5594791548977517
# Average MCC: 0.12852274706486624

# %%
# international

import pandas as pd
import numpy as np
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, f1_score, roc_auc_score, matthews_corrcoef
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from imblearn.over_sampling import RandomOverSampler

data = pd.read_csv("C:\\Users\\co279\\penalty_international.csv")

data = data.iloc[:, 4:]
data.dropna(inplace=True)

# data preprocessing
data = pd.get_dummies(data, columns=['position'])
data = pd.get_dummies(data, columns=['order'])

label_encoder = LabelEncoder()
data['score'] = label_encoder.fit_transform(data['score'])

X = data.drop(columns=['score'])
y = data['score']

accuracy_list = []
f1_list = []
roc_list = []
mcc_list = []

# iteration = 5
n_iterations = 5

for i in range(n_iterations):
    # data spliting (train, test)
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=411 + i, stratify=y)

    # oversampling
    oversampler = RandomOverSampler(sampling_strategy='minority', random_state=411)
    X_resampled, y_resampled = oversampler.fit_resample(X_train, y_train)

    # multi-layer perceptron
    model = Sequential()
    model.add(Dense(64, activation='relu', input_shape=(X_resampled.shape[1],)))
    model.add(Dense(32, activation='relu'))
    model.add(Dense(16, activation='relu'))
    model.add(Dense(1, activation='sigmoid'))

    # model compiling
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

    # model fitting
    model.fit(X_resampled, y_resampled, epochs=10, batch_size=8, validation_data=(X_test, y_test), callbacks=[tf.keras.callbacks.EarlyStopping(patience=3, monitor='val_loss')])

    y_pred_prob = model.predict(X_test)
    y_pred = [1 if prob > 0.5 else 0 for prob in y_pred_prob]

    # model evaluation
    accuracy = accuracy_score(y_test, y_pred)
    f1 = f1_score(y_test, y_pred)
    roc = roc_auc_score(y_test, y_pred)
    mcc = matthews_corrcoef(y_test, y_pred)

    accuracy_list.append(accuracy)
    f1_list.append(f1)
    roc_list.append(roc)
    mcc_list.append(mcc)

    print(f"Iteration {i+1} - accuracy: {accuracy}, f1_score: {f1}, roc_auc: {roc}, MCC: {mcc}")

# average
avg_accuracy = np.mean(accuracy_list)
avg_f1 = np.mean(f1_list)
avg_roc = np.mean(roc_list)
avg_mcc = np.mean(mcc_list)

print("\nAverage Metrics after 5 Iterations:")
print(f"Average accuracy: {avg_accuracy}")
print(f"Average f1_score: {avg_f1}")
print(f"Average roc_auc: {avg_roc}")
print(f"Average MCC: {avg_mcc}")
# Out:
# Epoch 1/10
# 73/73 [==============================] - 2s 7ms/step - loss: 0.7127 - accuracy: 0.5567 - val_loss: 0.6737 - val_accuracy: 0.6667
# Epoch 2/10
# 73/73 [==============================] - 0s 3ms/step - loss: 0.6972 - accuracy: 0.5722 - val_loss: 0.6833 - val_accuracy: 0.6471
# Epoch 3/10
# 73/73 [==============================] - 0s 3ms/step - loss: 0.7124 - accuracy: 0.5722 - val_loss: 0.6982 - val_accuracy: 0.5882
# Epoch 4/10
# 73/73 [==============================] - 0s 3ms/step - loss: 0.7054 - accuracy: 0.5567 - val_loss: 0.7080 - val_accuracy: 0.4706
# 4/4 [==============================] - 0s 2ms/step
# Iteration 1 - accuracy: 0.47058823529411764, f1_score: 0.35714285714285715, roc_auc: 0.48464808691544636, MCC: -0.027785783912241586
# Epoch 1/10
# 73/73 [==============================] - 2s 7ms/step - loss: 0.9289 - accuracy: 0.5103 - val_loss: 0.6685 - val_accuracy: 0.5490
# Epoch 2/10
# 73/73 [==============================] - 0s 3ms/step - loss: 0.7160 - accuracy: 0.5309 - val_loss: 0.7806 - val_accuracy: 0.3137
# Epoch 3/10
# 73/73 [==============================] - 0s 3ms/step - loss: 0.6899 - accuracy: 0.5275 - val_loss: 0.6853 - val_accuracy: 0.5196
# Epoch 4/10
# 73/73 [==============================] - 0s 3ms/step - loss: 0.7153 - accuracy: 0.5258 - val_loss: 1.0299 - val_accuracy: 0.2843
# 4/4 [==============================] - 0s 2ms/step
# Iteration 2 - accuracy: 0.28431372549019607, f1_score: 0.44274809160305345, roc_auc: 0.5, MCC: 0.0
# Epoch 1/10
# 73/73 [==============================] - 2s 6ms/step - loss: 1.0332 - accuracy: 0.4828 - val_loss: 0.6397 - val_accuracy: 0.6569
# Epoch 2/10
# 73/73 [==============================] - 0s 3ms/step - loss: 0.7049 - accuracy: 0.5017 - val_loss: 0.6929 - val_accuracy: 0.5098
# Epoch 3/10
# 73/73 [==============================] - 0s 3ms/step - loss: 0.6985 - accuracy: 0.5378 - val_loss: 0.7233 - val_accuracy: 0.4510
# Epoch 4/10
# 73/73 [==============================] - 0s 2ms/step - loss: 0.7147 - accuracy: 0.5155 - val_loss: 0.7576 - val_accuracy: 0.3529
# 4/4 [==============================] - 0s 2ms/step
# Iteration 3 - accuracy: 0.35294117647058826, f1_score: 0.45, roc_auc: 0.5271610769957487, MCC: 0.07899877785206605
# Epoch 1/10
# 73/73 [==============================] - 2s 6ms/step - loss: 0.7574 - accuracy: 0.4914 - val_loss: 1.1918 - val_accuracy: 0.2843
# Epoch 2/10
# 73/73 [==============================] - 0s 3ms/step - loss: 0.7368 - accuracy: 0.4914 - val_loss: 0.6378 - val_accuracy: 0.6667
# Epoch 3/10
# 73/73 [==============================] - 0s 2ms/step - loss: 0.7286 - accuracy: 0.5361 - val_loss: 0.6230 - val_accuracy: 0.6961
# Epoch 4/10
# 73/73 [==============================] - 0s 3ms/step - loss: 0.7155 - accuracy: 0.5120 - val_loss: 0.6409 - val_accuracy: 0.6667
# Epoch 5/10
# 73/73 [==============================] - 0s 2ms/step - loss: 0.7083 - accuracy: 0.4914 - val_loss: 0.6309 - val_accuracy: 0.6667
# Epoch 6/10
# 73/73 [==============================] - 0s 2ms/step - loss: 0.7143 - accuracy: 0.5017 - val_loss: 0.8067 - val_accuracy: 0.3333
# 4/4 [==============================] - 0s 1ms/step
# Iteration 4 - accuracy: 0.3333333333333333, f1_score: 0.423728813559322, roc_auc: 0.49267831837505904, MCC: -0.01980772442907568
# Epoch 1/10
# 73/73 [==============================] - 2s 6ms/step - loss: 0.8774 - accuracy: 0.5206 - val_loss: 0.6815 - val_accuracy: 0.4314
# Epoch 2/10
# 73/73 [==============================] - 0s 3ms/step - loss: 0.7000 - accuracy: 0.5189 - val_loss: 0.6605 - val_accuracy: 0.6471
# Epoch 3/10
# 73/73 [==============================] - 0s 3ms/step - loss: 0.7256 - accuracy: 0.5223 - val_loss: 0.6666 - val_accuracy: 0.5294
# Epoch 4/10
# 73/73 [==============================] - 0s 3ms/step - loss: 0.7013 - accuracy: 0.5258 - val_loss: 0.6635 - val_accuracy: 0.6275
# Epoch 5/10
# 73/73 [==============================] - 0s 3ms/step - loss: 0.6823 - accuracy: 0.5653 - val_loss: 0.6887 - val_accuracy: 0.5294
# 4/4 [==============================] - 0s 2ms/step
# Iteration 5 - accuracy: 0.5294117647058824, f1_score: 0.25, roc_auc: 0.4529995276334436, MCC: -0.08931434628787992
#
# Average Metrics after 5 Iterations:
# Average accuracy: 0.3941176470588236
# Average f1_score: 0.3847239524610465
# Average roc_auc: 0.4914974019839396
# Average MCC: -0.011581815355426225
